# %% [markdown]
# # Exemplo: Primeiros passos
# --------------------------
#
# Este exemplo mostra como começar a usar a biblioteca experionml.
#
# Os dados utilizados são uma variação do [conjunto de dados de clima australiano](https://www.kaggle.com/jsphyg/weather-dataset-rattle-package) do Kaggle. Você pode baixá-lo [aqui](https://github.com/tvdboom/ExperionML/blob/master/examples/datasets/weatherAUS.csv). O objetivo deste conjunto é prever se vai chover amanhã treinando um classificador binário com a variável alvo `RainTomorrow`.

# %%
import pandas as pd
from experionml import ExperionMLClassifier

# Carrega o conjunto de dados Australian Weather
X = pd.read_csv("./datasets/weatherAUS.csv")

# %%
experionml = ExperionMLClassifier(X, y="RainTomorrow", verbose=2)
# Out:
# << ================== ExperionML ================== >>
#
# Configuração ==================== >>
# Tarefa do algoritmo: Binary classification.
#
# Estatísticas do conjunto de dados ==================== >>
# Formato: (142193, 22)
# Tamanho do conjunto de train: 113755
# Tamanho do conjunto de test: 28438
# -------------------------------------
# Memória: 25.03 MB
# Escalonado: False
# Valores ausentes: 316559 (10.1%)
# Atributos categóricos: 5 (23.8%)
# Duplicatas: 45 (0.0%)

# %%
experionml.impute(strat_num="median", strat_cat="most_frequent")  
experionml.encode(strategy="Target", max_onehot=8)
# Out:
# Ajustando Imputer...
# Imputando valores ausentes...
#  --> Imputando 7 valores ausentes com median (11.7) na coluna MinTemp.
#  --> Imputando 2 valores ausentes com median (22.5) na coluna MaxTemp.
#  --> Imputando 11 valores ausentes com median (0.0) na coluna Rainfall.
#  --> Imputando 439 valores ausentes com median (4.8) na coluna Evaporation.
#  --> Imputando 490 valores ausentes com median (8.8) na coluna Sunshine.
#  --> Imputando 73 valores ausentes com most_frequent (W) na coluna WindGustDir.
#  --> Imputando 73 valores ausentes com median (39.0) na coluna WindGustSpeed.
#  --> Imputando 76 valores ausentes com most_frequent (N) na coluna WindDir9am.
#  --> Imputando 22 valores ausentes com most_frequent (W) na coluna WindDir3pm.
#  --> Imputando 7 valores ausentes com median (13.0) na coluna WindSpeed9am.
#  --> Imputando 17 valores ausentes com median (19.0) na coluna WindSpeed3pm.
#  --> Imputando 14 valores ausentes com median (70.0) na coluna Humidity9am.
#  --> Imputando 25 valores ausentes com median (52.0) na coluna Humidity3pm.
#  --> Imputando 112 valores ausentes com median (1017.7) na coluna Pressure9am.
#  --> Imputando 111 valores ausentes com median (1015.3) na coluna Pressure3pm.
#  --> Imputando 406 valores ausentes com median (5.0) na coluna Cloud9am.
#  --> Imputando 420 valores ausentes com median (5.0) na coluna Cloud3pm.
#  --> Imputando 7 valores ausentes com median (16.3) na coluna Temp9am.
#  --> Imputando 18 valores ausentes com median (20.8) na coluna Temp3pm.
#  --> Imputando 11 valores ausentes com most_frequent (No) na coluna RainToday.
# Ajustando Encoder...
# Codificando colunas categóricas...
#  --> Aplicando Target-encoding à variável Location. Ela contém 49 classes.
#  --> Aplicando Target-encoding à variável WindGustDir. Ela contém 16 classes.
#  --> Aplicando Target-encoding à variável WindDir9am. Ela contém 16 classes.
#  --> Aplicando Target-encoding à variável WindDir3pm. Ela contém 16 classes.
#  --> Aplicando Ordinal-encoding à variável RainToday. Ela contém 2 classes.

# %%
experionml.run(models=["LDA", "AdaB"], metric="auc", n_trials=10)
# Out:
# Training ========================= >>
# Models: LDA, AdaB
# Metric: auc
#
#
# Running hyperparameter tuning for LinearDiscriminantAnalysis...
# | trial |  solver | shrinkage |     auc | best_auc | time_trial | time_ht |    state |
# | ----- | ------- | --------- | ------- | -------- | ---------- | ------- | -------- |
# | 0     |   eigen |       0.7 |  0.8323 |   0.8323 |     0.120s |  0.120s | COMPLETE |
# | 1     |     svd |       nan |  0.7273 |   0.8323 |     0.115s |  0.235s | COMPLETE |
# | 2     |    lsqr |       1.0 |  0.8139 |   0.8323 |     0.171s |  0.406s | COMPLETE |
# | 3     |   eigen |       1.0 |  0.8685 |   0.8685 |     0.112s |  0.518s | COMPLETE |
# | 4     |    lsqr |       0.8 |  0.8299 |   0.8685 |     0.116s |  0.633s | COMPLETE |
# | 5     |    lsqr |      auto |  0.7884 |   0.8685 |     0.115s |  0.749s | COMPLETE |
# | 6     |    lsqr |       0.6 |  0.8671 |   0.8685 |     0.111s |  0.859s | COMPLETE |
# | 7     |    lsqr |       0.6 |  0.8671 |   0.8685 |     0.001s |  0.860s | COMPLETE |
# | 8     |   eigen |       0.9 |   0.807 |   0.8685 |     0.113s |  0.973s | COMPLETE |
# | 9     |     svd |      None |  0.7273 |   0.8685 |     0.001s |  0.973s | COMPLETE |
# Hyperparameter tuning ---------------------------
# Best trial --> 3
# Best parameters:
#  --> solver: eigen
#  --> shrinkage: 1.0
# Best evaluation --> auc: 0.8685
# Time elapsed: 0.973s
# Fit ---------------------------------------------
# Train evaluation --> auc: 0.8049
# Test evaluation --> auc: 0.7696
# Time elapsed: 0.036s
# -------------------------------------------------
# Time: 1.010s
#
#
# Running hyperparameter tuning for AdaBoost...
# | trial | n_estimators | learning_rate |     auc | best_auc | time_trial | time_ht |    state |
# | ----- | ------------ | ------------- | ------- | -------- | ---------- | ------- | -------- |
# | 0     |          300 |        0.1111 |  0.7995 |   0.7995 |     0.686s |  0.686s | COMPLETE |
# | 1     |          450 |        1.0436 |  0.6273 |   0.7995 |     0.943s |  1.629s | COMPLETE |
# | 2     |          430 |        0.0677 |   0.706 |   0.7995 |     1.056s |  2.685s | COMPLETE |
# | 3     |          360 |        0.0229 |  0.7752 |   0.7995 |     0.931s |  3.616s | COMPLETE |
# | 4     |          220 |        0.0607 |  0.8234 |   0.8234 |     0.589s |  4.205s | COMPLETE |
# | 5     |          410 |        0.0647 |  0.7671 |   0.8234 |     0.826s |  5.031s | COMPLETE |
# | 6     |          420 |        8.3891 |  0.6351 |   0.8234 |     0.846s |  5.877s | COMPLETE |
# | 7     |          360 |        2.2194 |   0.752 |   0.8234 |     0.744s |  6.621s | COMPLETE |
# | 8     |          280 |        0.0388 |  0.8227 |   0.8234 |     0.666s |  7.287s | COMPLETE |
# | 9     |          330 |        1.1942 |  0.7752 |   0.8234 |     0.681s |  7.968s | COMPLETE |
# Hyperparameter tuning ---------------------------
# Best trial --> 4
# Best parameters:
#  --> n_estimators: 220
#  --> learning_rate: 0.0607
# Best evaluation --> auc: 0.8234
# Time elapsed: 7.968s
# Fit ---------------------------------------------
# Train evaluation --> auc: 0.921
# Test evaluation --> auc: 0.8092
# Time elapsed: 0.599s
# -------------------------------------------------
# Time: 8.567s
#
#
# Resultados finais ==================== >>
# Tempo total: 11.549s
# -------------------------------------
# LinearDiscriminantAnalysis --> auc: 0.7696
# AdaBoost                   --> auc: 0.8092 !

# %%
experionml.evaluate()
# Out:
# <style type="text/css">
# #T_2d215_row0_col1, #T_2d215_row0_col2, #T_2d215_row0_col3, #T_2d215_row0_col4, #T_2d215_row0_col7, #T_2d215_row1_col0, #T_2d215_row1_col5, #T_2d215_row1_col6, #T_2d215_row1_col8 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2d215">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2d215_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_2d215_level0_col1" class="col_heading level0 col1" >ap</th>
#       <th id="T_2d215_level0_col2" class="col_heading level0 col2" >ba</th>
#       <th id="T_2d215_level0_col3" class="col_heading level0 col3" >f1</th>
#       <th id="T_2d215_level0_col4" class="col_heading level0 col4" >jaccard</th>
#       <th id="T_2d215_level0_col5" class="col_heading level0 col5" >mcc</th>
#       <th id="T_2d215_level0_col6" class="col_heading level0 col6" >precision</th>
#       <th id="T_2d215_level0_col7" class="col_heading level0 col7" >recall</th>
#       <th id="T_2d215_level0_col8" class="col_heading level0 col8" >auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d215_level0_row0" class="row_heading level0 row0" >LDA</th>
#       <td id="T_2d215_row0_col0" class="data row0 col0" >0.755000</td>
#       <td id="T_2d215_row0_col1" class="data row0 col1" >0.607600</td>
#       <td id="T_2d215_row0_col2" class="data row0 col2" >0.678900</td>
#       <td id="T_2d215_row0_col3" class="data row0 col3" >0.484200</td>
#       <td id="T_2d215_row0_col4" class="data row0 col4" >0.319400</td>
#       <td id="T_2d215_row0_col5" class="data row0 col5" >0.330200</td>
#       <td id="T_2d215_row0_col6" class="data row0 col6" >0.434000</td>
#       <td id="T_2d215_row0_col7" class="data row0 col7" >0.547600</td>
#       <td id="T_2d215_row0_col8" class="data row0 col8" >0.769600</td>
#     </tr>
#     <tr>
#       <th id="T_2d215_level0_row1" class="row_heading level0 row1" >AdaB</th>
#       <td id="T_2d215_row1_col0" class="data row1 col0" >0.835000</td>
#       <td id="T_2d215_row1_col1" class="data row1 col1" >0.594000</td>
#       <td id="T_2d215_row1_col2" class="data row1 col2" >0.659600</td>
#       <td id="T_2d215_row1_col3" class="data row1 col3" >0.476200</td>
#       <td id="T_2d215_row1_col4" class="data row1 col4" >0.312500</td>
#       <td id="T_2d215_row1_col5" class="data row1 col5" >0.424100</td>
#       <td id="T_2d215_row1_col6" class="data row1 col6" >0.714300</td>
#       <td id="T_2d215_row1_col7" class="data row1 col7" >0.357100</td>
#       <td id="T_2d215_row1_col8" class="data row1 col8" >0.809200</td>
#     </tr>
#   </tbody>
# </table>
