# %% [markdown]
# # Exemplo: Primeiros passos
# --------------------------
#
# Este exemplo mostra como começar a usar a biblioteca experionml.
#
# Os dados utilizados são uma variação do [conjunto de dados de clima australiano](https://www.kaggle.com/jsphyg/weather-dataset-rattle-package) do Kaggle. Você pode baixá-lo [aqui](https://github.com/tvdboom/ExperionML/blob/master/examples/datasets/weatherAUS.csv). O objetivo deste conjunto é prever se vai chover amanhã treinando um classificador binário com a variável alvo `RainTomorrow`.

# %%
import pandas as pd
from experionml import ExperionMLClassifier

# Carrega o conjunto de dados Australian Weather
X = pd.read_csv("./datasets/weatherAUS.csv")
# Out:
# /home/gerson/Projects/Personal/experionml/.venv/lib/python3.12/site-packages/featuretools/entityset/entityset.py:1379: SyntaxWarning: invalid escape sequence '\l'
#   columns_string = "\l".join(column_typing_info)  # noqa: W605
# /home/gerson/Projects/Personal/experionml/.venv/lib/python3.12/site-packages/featuretools/entityset/entityset.py:1381: SyntaxWarning: invalid escape sequence '\l'
#   label = "{%s (%d row%s)|%s\l}" % (  # noqa: W605

# %%
experionml = ExperionMLClassifier(X, y="RainTomorrow", verbose=2)
# Out:
# << ================== ExperionML ================== >>
#
# Configuração ==================== >>
# Tarefa do algoritmo: Binary classification.
#
# Estatísticas do conjunto de dados ==================== >>
# Formato: (142193, 22)
# Tamanho do conjunto de train: 113755
# Tamanho do conjunto de test: 28438
# -------------------------------------
# Memória: 25.03 MB
# Escalonado: False
# Valores ausentes: 316559 (10.1%)
# Atributos categóricos: 5 (23.8%)
# Duplicatas: 45 (0.0%)

# %%
experionml.impute(strat_num="median", strat_cat="most_frequent")  
experionml.encode(strategy="Target", max_onehot=8)
# Out:
# Ajustando Imputer...
# Imputando valores ausentes...
#  --> Imputando 637 valores ausentes com median (12.0) na coluna MinTemp.
#  --> Imputando 322 valores ausentes com median (22.6) na coluna MaxTemp.
#  --> Imputando 1406 valores ausentes com median (0.0) na coluna Rainfall.
#  --> Imputando 60843 valores ausentes com median (4.6) na coluna Evaporation.
#  --> Imputando 67816 valores ausentes com median (8.5) na coluna Sunshine.
#  --> Imputando 9330 valores ausentes com most_frequent (W) na coluna WindGustDir.
#  --> Imputando 9270 valores ausentes com median (39.0) na coluna WindGustSpeed.
#  --> Imputando 10013 valores ausentes com most_frequent (N) na coluna WindDir9am.
#  --> Imputando 3778 valores ausentes com most_frequent (SE) na coluna WindDir3pm.
#  --> Imputando 1348 valores ausentes com median (13.0) na coluna WindSpeed9am.
#  --> Imputando 2630 valores ausentes com median (19.0) na coluna WindSpeed3pm.
#  --> Imputando 1774 valores ausentes com median (70.0) na coluna Humidity9am.
#  --> Imputando 3610 valores ausentes com median (52.0) na coluna Humidity3pm.
#  --> Imputando 14014 valores ausentes com median (1017.6) na coluna Pressure9am.
#  --> Imputando 13981 valores ausentes com median (1015.2) na coluna Pressure3pm.
#  --> Imputando 53657 valores ausentes com median (5.0) na coluna Cloud9am.
#  --> Imputando 57094 valores ausentes com median (5.0) na coluna Cloud3pm.
#  --> Imputando 904 valores ausentes com median (16.7) na coluna Temp9am.
#  --> Imputando 2726 valores ausentes com median (21.1) na coluna Temp3pm.
#  --> Imputando 1406 valores ausentes com most_frequent (No) na coluna RainToday.
# Ajustando Encoder...
# Codificando colunas categóricas...
#  --> Aplicando Target-encoding à variável Location. Ela contém 49 classes.
#  --> Aplicando Target-encoding à variável WindGustDir. Ela contém 16 classes.
#  --> Aplicando Target-encoding à variável WindDir9am. Ela contém 16 classes.
#  --> Aplicando Target-encoding à variável WindDir3pm. Ela contém 16 classes.
#  --> Aplicando Ordinal-encoding à variável RainToday. Ela contém 2 classes.

# %%
experionml.run(models=["LDA", "AdaB"], metric="auc", n_trials=10)
# Out:
# Training ========================= >>
# Models: LDA, AdaB
# Metric: auc
#
#
# Executando ajuste de hiperparâmetros para LinearDiscriminantAnalysis...
# | trial |  solver | shrinkage |     auc | best_auc | time_trial | time_ht |    state |
# | ----- | ------- | --------- | ------- | -------- | ---------- | ------- | -------- |
# | 0     |     svd |      None |  0.8679 |   0.8679 |     2.140s |  2.140s | COMPLETE |
# | 1     |     svd |      None |  0.8679 |   0.8679 |     0.004s |  2.143s | COMPLETE |
# | 2     |     svd |      None |  0.8679 |   0.8679 |     0.000s |  2.144s | COMPLETE |
# | 3     |   eigen |       0.6 |  0.8516 |   0.8679 |     2.042s |  4.186s | COMPLETE |
# | 4     |    lsqr |      auto |  0.8616 |   0.8679 |     2.066s |  6.252s | COMPLETE |
# | 5     |   eigen |       0.5 |  0.8438 |   0.8679 |     2.119s |  8.370s | COMPLETE |
# | 6     |    lsqr |       0.6 |  0.8436 |   0.8679 |     2.164s | 10.534s | COMPLETE |
# | 7     |    lsqr |      None |  0.8652 |   0.8679 |     2.054s | 12.588s | COMPLETE |
# | 8     |    lsqr |       0.6 |  0.8436 |   0.8679 |     0.001s | 12.588s | COMPLETE |
# | 9     |    lsqr |      auto |  0.8616 |   0.8679 |     0.001s | 12.589s | COMPLETE |
# Ajuste de hiperparâmetros ---------------------------
# Melhor trial --> 0
# Melhores parâmetros:
#  --> solver: svd
#  --> shrinkage: None
# Melhor avaliação --> auc: 0.8679
# Tempo decorrido: 12.589s
# Fit ---------------------------------------------
# Train avaliação --> auc: 0.862
# Test avaliação --> auc: 0.8653
# Tempo decorrido: 0.860s
# -------------------------------------------------
# Time: 13.449s
#
#
# Executando ajuste de hiperparâmetros para AdaBoost...
# | trial | n_estimators | learning_rate |     auc | best_auc | time_trial | time_ht |    state |
# | ----- | ------------ | ------------- | ------- | -------- | ---------- | ------- | -------- |
# | 0     |          180 |        0.0272 |  0.8511 |   0.8511 |    18.227s | 18.227s | COMPLETE |
# | 1     |          420 |        0.1008 |  0.8691 |   0.8691 |    41.572s | 59.799s | COMPLETE |
# | 2     |          180 |        8.4529 |  0.6863 |   0.8691 |    18.387s | 01m:18s | COMPLETE |
# | 3     |          130 |        0.0122 |  0.8264 |   0.8691 |    12.292s | 01m:30s | COMPLETE |
# | 4     |          260 |        1.1131 |  0.8687 |   0.8691 |    23.540s | 01m:54s | COMPLETE |
# | 5     |          300 |        6.1991 |  0.6923 |   0.8691 |    25.927s | 02m:20s | COMPLETE |
# | 6     |          170 |        0.2104 |  0.8688 |   0.8691 |    15.271s | 02m:35s | COMPLETE |
# | 7     |          140 |        0.0846 |   0.857 |   0.8691 |    12.418s | 02m:48s | COMPLETE |
# | 8     |          190 |        2.1591 |  0.6876 |   0.8691 |    16.344s | 03m:04s | COMPLETE |
# | 9     |          130 |         0.112 |  0.8622 |   0.8691 |    11.808s | 03m:16s | COMPLETE |
# Ajuste de hiperparâmetros ---------------------------
# Melhor trial --> 1
# Melhores parâmetros:
#  --> n_estimators: 420
#  --> learning_rate: 0.1008
# Melhor avaliação --> auc: 0.8691
# Tempo decorrido: 03m:16s
# Fit ---------------------------------------------
# Train avaliação --> auc: 0.868
# Test avaliação --> auc: 0.8696
# Tempo decorrido: 48.289s
# -------------------------------------------------
# Time: 04m:04s
#
#
# Resultados finais ==================== >>
# Tempo total: 04m:19s
# -------------------------------------
# LinearDiscriminantAnalysis --> auc: 0.8653
# AdaBoost                   --> auc: 0.8696 !

# %%
experionml.evaluate()
# Out:
# <style type="text/css">
# #T_e2c85_row0_col2, #T_e2c85_row0_col3, #T_e2c85_row0_col4, #T_e2c85_row0_col7, #T_e2c85_row1_col0, #T_e2c85_row1_col1, #T_e2c85_row1_col5, #T_e2c85_row1_col6, #T_e2c85_row1_col8 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e2c85">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2c85_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_e2c85_level0_col1" class="col_heading level0 col1" >ap</th>
#       <th id="T_e2c85_level0_col2" class="col_heading level0 col2" >ba</th>
#       <th id="T_e2c85_level0_col3" class="col_heading level0 col3" >f1</th>
#       <th id="T_e2c85_level0_col4" class="col_heading level0 col4" >jaccard</th>
#       <th id="T_e2c85_level0_col5" class="col_heading level0 col5" >mcc</th>
#       <th id="T_e2c85_level0_col6" class="col_heading level0 col6" >precision</th>
#       <th id="T_e2c85_level0_col7" class="col_heading level0 col7" >recall</th>
#       <th id="T_e2c85_level0_col8" class="col_heading level0 col8" >auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2c85_level0_row0" class="row_heading level0 row0" >LDA</th>
#       <td id="T_e2c85_row0_col0" class="data row0 col0" >0.843000</td>
#       <td id="T_e2c85_row0_col1" class="data row0 col1" >0.684500</td>
#       <td id="T_e2c85_row0_col2" class="data row0 col2" >0.725200</td>
#       <td id="T_e2c85_row0_col3" class="data row0 col3" >0.593600</td>
#       <td id="T_e2c85_row0_col4" class="data row0 col4" >0.422100</td>
#       <td id="T_e2c85_row0_col5" class="data row0 col5" >0.509400</td>
#       <td id="T_e2c85_row0_col6" class="data row0 col6" >0.706800</td>
#       <td id="T_e2c85_row0_col7" class="data row0 col7" >0.511700</td>
#       <td id="T_e2c85_row0_col8" class="data row0 col8" >0.865300</td>
#     </tr>
#     <tr>
#       <th id="T_e2c85_level0_row1" class="row_heading level0 row1" >AdaB</th>
#       <td id="T_e2c85_row1_col0" class="data row1 col0" >0.846400</td>
#       <td id="T_e2c85_row1_col1" class="data row1 col1" >0.701400</td>
#       <td id="T_e2c85_row1_col2" class="data row1 col2" >0.718600</td>
#       <td id="T_e2c85_row1_col3" class="data row1 col3" >0.587000</td>
#       <td id="T_e2c85_row1_col4" class="data row1 col4" >0.415500</td>
#       <td id="T_e2c85_row1_col5" class="data row1 col5" >0.513900</td>
#       <td id="T_e2c85_row1_col6" class="data row1 col6" >0.739000</td>
#       <td id="T_e2c85_row1_col7" class="data row1 col7" >0.486900</td>
#       <td id="T_e2c85_row1_col8" class="data row1 col8" >0.869600</td>
#     </tr>
#   </tbody>
# </table>
